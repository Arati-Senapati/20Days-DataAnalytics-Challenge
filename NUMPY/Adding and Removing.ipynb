# %%
import numpy as np

arr = np.array([20,40,60,80])
print(np.append(arr,90))
# Out:
# [20 40 60 80 90]

# %%
arr = np.array([20,40,60,80])
print(np.append(arr,[90,100]))
# Out:
# [ 20  40  60  80  90 100]

# %%
print(np.insert(arr,1,50)) #array,index,value
# Out:
# [20 50 40 60 80]

# %%
arr = np.array([[20,40],[60,80]])
print(np.insert(arr,1,[50,60], axis=1))
# Out:
# [[20 50 40]
#  [60 60 80]]

# %%
arr = np.array([[20,40],[60,80]])
print(np.insert(arr,1,[50,60], axis=0))
# Out:
# [[20 40]
#  [50 60]
#  [60 80]]

# %%
print(arr)
print(np.delete(arr,1))
# Out:
# [[20 40]
#  [60 80]]
# [20 60 80]

# %%
print(arr)
print(np.delete(arr,1,axis=0))
# Out:
# [[20 40]
#  [60 80]]
# [[20 40]]

# %%
print(arr)
print(np.delete(arr,1,axis=1))
# Out:
# [[20 40]
#  [60 80]]
# [[20]
#  [60]]
