# %%
a = [30,40,50]
b = [5,5,3]
print(a+b)
# Out:
# [30, 40, 50, 5, 5, 3]

# %%
#concatenate
import numpy as np

arr1 = np.array([30,40,50])
arr2 = np.array([5,5,3])
print(np.concatenate([arr1,arr2]))
# Out:
# [30 40 50  5  5  3]

# %%
arr1 = np.array([[30,40],[50,60]])
arr2 = np.array([[5,5],[3,3]])
print(np.concatenate([arr1,arr2],axis = 0))
# Out:
# [[30 40]
#  [50 60]
#  [ 5  5]
#  [ 3  3]]

# %%
arr1 = np.array([[30,40],[50,60]])
arr2 = np.array([[5,5],[3,3]])
print(np.concatenate([arr1,arr2],axis = 1))
# Out:
# [[30 40  5  5]
#  [50 60  3  3]]

# %%
print(np.hstack([arr1,arr2]))  #horizontal concatenation
# Out:
# [[30 40  5  5]
#  [50 60  3  3]]

# %%
print(np.vstack([arr1,arr2]))  #verital concatenation
# Out:
# [[30 40]
#  [50 60]
#  [ 5  5]
#  [ 3  3]]

# %%
arr1 = np.array([30,40,50,60,10,20])
print(np.array_split(arr1,3))
# Out:
# [array([30, 40]), array([50, 60]), array([10, 20])]

# %%
arr1 = np.array([30,40,50,60,10,20])
b = np.array_split(arr1,3)
print(b[1])
# Out:
# [50 60]

# %%
arr1 = np.array([[30,40,50],[60,10,20]])
b = np.array_split(arr1,3)
print(b)
# Out:
# [array([[30, 40, 50]]), array([[60, 10, 20]]), array([], shape=(0, 3), dtype=int64)]
