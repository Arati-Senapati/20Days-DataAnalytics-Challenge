# %%
import pandas as pd
data = pd.read_excel("Hotel_Bookings.xlsx")
print(data)
# Out:
#                hotel  is_canceled  arrival_date_year arrival_date_month  \
# 0       Resort Hotel            0               2015               July
# 1       Resort Hotel            0               2015               July
# 2       Resort Hotel            0               2015               July
# 3       Resort Hotel            0               2015               July
# 4       Resort Hotel            0               2015               July
# ...              ...          ...                ...                ...
# 119385    City Hotel            0               2017             August
# 119386    City Hotel            0               2017             August
# 119387    City Hotel            0               2017             August
# 119388    City Hotel            0               2017             August
# 119389    City Hotel            0               2017             August
#
#         adults  children  babies country reserved_room_type  \
# ...

# %%
data.loc[(data["room_status"] == "Desired"),"Get_D_room"] = "full-fill"
data.loc[(data["room_status"] == "UnDesired"),"Get_D_room"] = "no-full-fill"
print(data.head(10))
# Out:
#           hotel  is_canceled  arrival_date_year arrival_date_month  adults  \
# 0  Resort Hotel            0               2015               July       2
# 1  Resort Hotel            0               2015               July       2
# 2  Resort Hotel            0               2015               July       1
# 3  Resort Hotel            0               2015               July       1
# 4  Resort Hotel            0               2015               July       2
# 5  Resort Hotel            0               2015               July       2
# 6  Resort Hotel            0               2015               July       2
# 7  Resort Hotel            0               2015               July       2
# 8  Resort Hotel            1               2015               July       2
# 9  Resort Hotel            1               2015               July       2
#
#    children  babies country reserved_room_type assigned_room_type  \
# 0       0.0       0     PRT                  C                  C
# ...

# %%
data = pd.read_excel("Company.xlsx")
print(data)
# Out:
#     EEID first-name last-name gender    salary
# 0  EMP01     ayushi    sharma      F  250000.0
# 1  EMP02      rohit      sahu      M       NaN
# 2  EMP03   pranjali  banerjee    NaN   27000.0
# 3  EMP01     ayushi    sharma      F   20000.0
# 4  EMP05        NaN     patel      M       NaN
# 5  EMP06      rohit     nayak      M   25000.0

# %%
data["Full Name"] = data["first-name"].str.capitalize()+" "+data["last-name"].str.capitalize()
print(data)
# Out:
#     EEID first-name last-name gender    salary          Full Name
# 0  EMP01     ayushi    sharma      F  250000.0      Ayushi Sharma
# 1  EMP02      rohit      sahu      M       NaN         Rohit Sahu
# 2  EMP03   pranjali  banerjee    NaN   27000.0  Pranjali Banerjee
# 3  EMP01     ayushi    sharma      F   20000.0      Ayushi Sharma
# 4  EMP05        NaN     patel      M       NaN                NaN
# 5  EMP06      rohit     nayak      M   25000.0        Rohit Nayak

# %%
import pandas as pd
data = pd.read_excel("Company.xlsx")
print(data)
# Out:
#     EEID first-name last-name gender  salary
# 0  EMP01     ayushi    sharma      F   25000
# 1  EMP02      rohit      sahu      M   25000
# 2  EMP03   pranjali  banerjee    NaN   27000
# 3  EMP01     ayushi    sharma      F   20000
# 4  EMP05        NaN     patel      M   20000
# 5  EMP06      rohit     nayak      M   25000

# %%
data["Bonus"] =(data["salary"]/100)*20
print(data)
# Out:
#     EEID first-name last-name gender  salary   Bonus
# 0  EMP01     ayushi    sharma      F   25000  5000.0
# 1  EMP02      rohit      sahu      M   25000  5000.0
# 2  EMP03   pranjali  banerjee    NaN   27000  5400.0
# 3  EMP01     ayushi    sharma      F   20000  4000.0
# 4  EMP05        NaN     patel      M   20000  4000.0
# 5  EMP06      rohit     nayak      M   25000  5000.0

# %%
data1 = {"Months":['January','February','March','April']}
a =pd.DataFrame(data1)
print(a)
# Out:
#      Months
# 0   January
# 1  February
# 2     March
# 3     April

# %%
def extract(value):
    return value[0:3]
a["Short_months"]= a["Months"].map(extract)
print(a)
# Out:
#      Months Short_months
# 0   January          Jan
# 1  February          Feb
# 2     March          Mar
# 3     April          Apr
